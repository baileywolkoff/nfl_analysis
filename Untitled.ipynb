# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_odds_rai = pd.read_csv('data/NFLML/RAI/RAI WeeklyOdds All Years.csv', index_col=0)
df_scores_rai = pd.read_csv('data/NFLML/RAI/RAI WeeklyScores All Years.csv', index_col=0)

# %%
df_odds_rai.loc[df_odds_rai['Year']==1978]
# Out:
#     G#   Opp  Spread  Over/Under    Result vs. Line OU Result  Year
# 0    1  @DEN    -4.0         0.0   L, 6-14     Lost      Over  1978
# 1    2  @SDG    -5.5         0.0  W, 21-20     Lost      Over  1978
# 2    3  @GNB    -9.5         0.0   W, 28-3      Won      Over  1978
# 3    4   NWE    -6.5         0.0  L, 14-21     Lost      Over  1978
# 4    5  @CHI    -6.5         0.0  W, 25-19     Lost      Over  1978
# 5    6   HOU    -7.5         0.0  W, 21-17     Lost      Over  1978
# 6    7   KAN   -13.5         0.0   W, 28-6      Won      Over  1978
# 7    8  @SEA    -7.0         0.0   L, 7-27     Lost      Over  1978
# 8    9   SDG    -6.5         0.0  L, 23-27     Lost      Over  1978
# 9   10  @KAN    -6.5         0.0  W, 20-10      Won      Over  1978
# 10  11  @CIN    -6.0         0.0  W, 34-21      Won      Over  1978
# 11  12   DET    -7.0         0.0  W, 29-17      Won      Over  1978
# 12  13   SEA    -8.0         0.0  L, 16-17     Lost      Over  1978
# ...

# %%
df_scores_rai.loc[df_scores_rai['Year']==1978]
# Out:
#     Week  Day          Date       Time Outcome     OT  Rec   Home  \
# 282    1  Sun   September 3  4:00PM ET       L  False  0-1  False
# 283    2  Sun  September 10  4:00PM ET       W  False  1-1  False
# 284    3  Sun  September 17  2:00PM ET       W  False  2-1  False
# 285    4  Sun  September 24  9:00PM ET       L  False  2-2   True
# 286    5  Sun     October 1  4:00PM ET       W   True  3-2  False
# 287    6  Sun     October 8  4:00PM ET       W  False  4-2   True
# 288    7  Sun    October 15  4:00PM ET       W  False  5-2   True
# 289    8  Sun    October 22  4:00PM ET       L  False  5-3  False
# 290    9  Sun    October 29  4:00PM ET       L  False  5-4   True
# 291   10  Sun    November 5  2:00PM ET       W  False  6-4  False
# 292   11  Mon   November 13  9:00PM ET       W  False  7-4  False
# 293   12  Sun   November 19  4:00PM ET       W  False  8-4   True
# 294   13  Sun   November 26  4:00PM ET       L  False  8-5   True
# ...

# %%
sns.distplot(df['Spread'])
# Out:
# C:\Users\bwolk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Spread', ylabel='Density'>

# %%
df.describe()
# Out:
#                G#      Spread  Over/Under         Year
# count  706.000000  706.000000  706.000000   706.000000
# mean     8.718130    0.400142   41.243626  1998.974504
# std      4.816772    6.112794    8.286757    12.410676
# min      1.000000  -18.000000    0.000000  1978.000000
# 25%      5.000000   -3.500000   39.000000  1988.000000
# 50%      9.000000    1.000000   42.000000  1999.000000
# 75%     13.000000    4.500000   45.000000  2010.000000
# max     20.000000   16.500000   60.000000  2021.000000

# %%
df.groupby('Year')['Spread'].mean()
# Out:
# Year
# 1978   -5.937500
# 1979   -1.750000
# 1980   -0.025000
# 1981   -1.281250
# 1982   -1.909091
# 1983   -4.210526
# 1984   -4.852941
# 1985   -3.205882
# 1986   -3.500000
# 1987   -2.266667
# 1988    0.062500
# 1989    0.281250
# 1990   -2.194444
# 1991   -1.205882
# 1992    1.343750
# 1993   -0.583333
# 1994   -1.625000
# 1995   -3.625000
# 1996   -0.875000
# 1997   -0.187500
# 1998    2.156250
# 1999   -0.031250
# 2000   -4.444444
# 2001   -4.750000
# 2002   -4.131579
# 2003    2.281250
# 2004    3.000000
# 2005    2.468750
# 2006    6.875000
# 2007    4.843750
# 2008    6.500000
# 2009    8.593750
# 2010    3.187500
# 2011    1.593750
# 2012    3.718750
# 2013    6.031250
# 2014    8.250000
# 2015    2.062500
# 2016   -0.617647
# 2017    0.156250
# 2018    5.937500
# 2019    2.718750
# 2020    1.125000
# 2021    5.000000
# Name: Spread, dtype: float64
